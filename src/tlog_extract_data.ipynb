# %% [markdown]
# <a href="https://colab.research.google.com/github/EnPaiva93/Proyecto-UCA-Drone/blob/main/src/tlog_extract_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np 
import ast

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c4a78e46-4f2a-43c0-b188-7771e2ec7709" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4a78e46-4f2a-43c0-b188-7771e2ec7709">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ATTITUDE_TARGET.csv to ATTITUDE_TARGET.csv

# %%
file_name = list(uploaded.keys())[0]
df = pd.read_csv (file_name, sep = ';')
headers_names = list(df.columns.values)[0].split(",")
values_list = [list(ast.literal_eval(x[0])) for x in df.values.tolist()]
df2 = pd.DataFrame(np.array(values_list, dtype=object))
df2.columns = list(df.columns.values)[0].split(",")
df2

# %%
file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name, sep = ';')
headers_names = list(df.columns.values)[0].split(",")

# %%
headers_names
# Out:
# ['timestamp',
#  'ATTITUDE_TARGET.time_boot_ms',
#  'ATTITUDE_TARGET.type_mask',
#  'ATTITUDE_TARGET.q',
#  'ATTITUDE_TARGET.body_roll_rate',
#  'ATTITUDE_TARGET.body_pitch_rate',
#  'ATTITUDE_TARGET.body_yaw_rate',
#  'ATTITUDE_TARGET.thrust']

# %%
[x.find('.q')>0 for x in headers_names]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b3a3dc11c88a> in <module>()
# ----> 1 [x.find('.q')>0 for x in headers_names]
#
# NameError: name 'headers_names' is not defined

# %%
a = df.values.tolist()
a = [[x[0].replace('[', '')] for x in a]
a = [[x[0].replace(']', '')] for x in a]
a = [x[0].split(',') for x in a]
a
# Out:
# [['1631220720.31799984',
#   '78388',
#   '0',
#   '0.43972763419151306',
#   ' 0.0',
#   ' 0.0',
#   ' 0.8981311917304993',
#   '1.1040483713150024',
#   '0.20407357811927795',
#   '0.007118212524801493',
#   '0.0'],
#  ['1631220721.21599984',
#   '79019',
#   '0',
#   '0.44380709528923035',
#   ' 0.0',
#   ' 0.0',
#   ' 0.8961223363876343',
#   '0.8771044611930847',
#   '0.14444240927696228',
#   '0.00321944965980947',
#   '0.0'],
#  ['1631220722.90799999',
#   '79650',
#   '0',
#   '0.3409472107887268',
#   ' 0.0',
#   ' 0.0',
#   ' 0.9400824308395386',
#   '2.038820266723633',
#   '0.22398711740970612',
#   '0.017265483736991882',
#   '0.0'],
#  ['1631220722.90999985',
#   '80281',
#   '0',
#   '0.43782979249954224',
#   ' 0.0',
#   ' 0.0',
#   ' 0.8990578651428223',
#   '2.5733885765075684',
#   '-0.24076609313488007',
#   '-0.019290868192911148',
#   '0.0'],
#  ['1631220722.91199994',
#   '80912',
#   '0',
#   '0.49625012278556824',
#   ' 0.0',
#   ' 0.0',
#   ' 0.8681795597076416',
#   '3.2899832725524902',
#   '-0.940633237361908',
#   '-0.09287154674530029',
#   '0.0'],
#  ['1631220723.49899983',
#   '81539',
#   '0',
#   '0.6883761882781982',
#   ' 0.0',
#   ' 0.0',
#   ' 0.7253538966178894',
#   '1.7009060382843018',
#   '-0.7849462032318115',
#   '-0.03447744622826576',
#   '0.0'],
#  ['1631220724.13800001',
#   '82161',
#   '0',
#   '0.7412158250808716',
#   ' 0.0',
#   ' 0.0',
#   ' 0.6712667346000671',
#   '3.7723493576049805',
#   '-1.1498217582702637',
#   '-0.14024250209331512',
#   '0.0'],
#  ['1631220724.72399998',
#   '82801',
#   '0',
#   '0.7986190319061279',
#   ' 0.0',
#   ' 0.0',
#   ' 0.6018369197845459',
#   '3.6195297241210938',
#   '-0.26194143295288086',
#   '-0.027608783915638924',
#   '0.0'],
#  ['1631220725.36199999',
#   '83418',
#   '0',
#   '0.8077508211135864',
#   ' 0.0',
#   ' 0.0',
#   ' 0.5895240902900696',
#   '3.83972430229187',
#   '-0.7997480034828186',
#   '-0.10981491953134537',
#   '0.0'],
#  ['1631220726.10899997',
#   '84058',
#   '0',
#   '0.8184155821800232',
#   ' 0.0',
#   ' 0.0',
#   ' 0.5746268033981323',
#   '3.83972430229187',
#   '-0.8178913593292236',
#   '-0.10905858129262924',
#   '0.0'],
#  ['1631220726.51999998',
#   '84680',
#   '0',
#   '0.8607766032218933',
#   ' 0.0',
#   ' 0.0',
#   ' 0.5089828968048096',
#   '-0.9065858721733093',
#   '-0.14430966973304749',
#   '0.003931504208594561',
#   '0.0'],
#  ['1631220727.44299984',
#   '85316',
#   '0',
#   '0.8623355627059937',
#   ' 0.0',
#   ' 0.0',
#   ' 0.5063371658325195',
#   '-0.2448146641254425',
#   '0.1606457382440567',
#   '-0.0011193369282409549',
#   '0.0'],
#  ['1631220728.06499982',
#   '85938',
#   '0',
#   '0.8637687563896179',
#   ' 0.0',
#   ' 0.0',
#   ' 0.5038883686065674',
#   '-0.21140094101428986',
#   '0.19290798902511597',
#   '-0.0011958257528021932',
#   '0.0'],
#  ['1631220728.46899986',
#   '86569',
#   '0',
#   '0.8651624321937561',
#   ' 0.0',
#   ' 0.0',
#   ' 0.5014917254447937',
#   '-0.1734468638896942',
#   '0.23264753818511963',
#   '-0.0012227868428453803',
#   '0.0'],
#  ['1631220729.01899981',
#   '87200',
#   '0',
#   '0.8664902448654175',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4991939663887024',
#   '-0.13689924776554108',
#   '0.26369261741638184',
#   '-0.0010902432259172201',
#   '0.0'],
#  ['1631220729.91199994',
#   '87827',
#   '0',
#   '0.8676969408988953',
#   ' 0.0',
#   ' 0.0',
#   ' 0.49709352850914',
#   '-0.10425206273794174',
#   '0.2856862246990204',
#   '-0.0009071538224816322',
#   '0.0'],
#  ['1631220730.61599994',
#   '88462',
#   '0',
#   '0.8689024448394775',
#   ' 0.0',
#   ' 0.0',
#   ' 0.49498337507247925',
#   '-0.07676622271537781',
#   '0.2975793778896332',
#   '-0.0006491907988674939',
#   '0.0'],
#  ['1631220731.12999988',
#   '89089',
#   '0',
#   '0.8699640035629272',
#   ' 0.0',
#   ' 0.0',
#   ' 0.49311524629592896',
#   '-0.055996496230363846',
#   '0.30065131187438965',
#   '-0.0004639551625587046',
#   '0.0'],
#  ['1631220731.68700004',
#   '89724',
#   '0',
#   '0.8709690570831299',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4913378655910492',
#   '-0.0423024445772171',
#   '0.29611411690711975',
#   '-0.00034489334211684763',
#   '0.0'],
#  ['1631220732.16199994',
#   '90346',
#   '0',
#   '0.8719596266746521',
#   ' 0.0',
#   ' 0.0',
#   ' 0.48957785964012146',
#   '-0.033662959933280945',
#   '0.28477591276168823',
#   '-0.00023735174909234047',
#   '0.0'],
#  ['1631220732.93599987',
#   '90977',
#   '0',
#   '0.8729510307312012',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4878078103065491',
#   '-0.030425986275076866',
#   '0.2686200439929962',
#   '-0.00018611016275826842',
#   '0.0'],
#  ['1631220733.51300001',
#   '91604',
#   '0',
#   '0.8739009499549866',
#   ' 0.0',
#   ' 0.0',
#   ' 0.48610398173332214',
#   '-0.030520539730787277',
#   '0.2494570016860962',
#   '-0.00018562297918833792',
#   '0.0'],
#  ['1631220734.17799997',
#   '92231',
#   '0',
#   '0.8748618960380554',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4843723773956299',
#   '-0.034306518733501434',
#   '0.2288254201412201',
#   '-0.00018426710448693484',
#   '0.0'],
#  ['1631220734.82699990',
#   '92871',
#   '0',
#   '0.8757930994033813',
#   ' 0.0',
#   ' 0.0',
#   ' 0.48268669843673706',
#   '-0.039707016199827194',
#   '0.207797110080719',
#   '-0.00020241824677214026',
#   '0.0'],
#  ['1631220735.52300000',
#   '93488',
#   '0',
#   '0.876686155796051',
#   ' 0.0',
#   ' 0.0',
#   ' 0.48106276988983154',
#   '-0.047011859714984894',
#   '0.18791607022285461',
#   '-0.0002341920480830595',
#   '0.0'],
#  ['1631220736.17599988',
#   '94119',
#   '0',
#   '0.8775263428688049',
#   ' 0.0',
#   ' 0.0',
#   ' 0.47952842712402344',
#   '-0.054957274347543716',
#   '0.16954340040683746',
#   '-0.00024021828721743077',
#   '0.0'],
#  ['1631220736.70799994',
#   '94759',
#   '0',
#   '0.8783316612243652',
#   ' 0.0',
#   ' 0.0',
#   ' 0.47805169224739075',
#   '-0.0634092167019844',
#   '0.1534365564584732',
#   '-0.0002594688266981393',
#   '0.0'],
#  ['1631220737.19899988',
#   '95377',
#   '0',
#   '0.8790804147720337',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4766734540462494',
#   '-0.07092741876840591',
#   '0.14064429700374603',
#   '-0.0002525204326957464',
#   '0.0'],
#  ['1631220737.80999994',
#   '96012',
#   '0',
#   '0.8797913789749146',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4753600060939789',
#   '-0.07794841378927231',
#   '0.12933017313480377',
#   '-0.00027825895813293755',
#   '0.0'],
#  ['1631220738.75699997',
#   '96643',
#   '0',
#   '0.8804506659507751',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4741377830505371',
#   '-0.08394565433263779',
#   '0.12084756791591644',
#   '-0.0002886542060878128',
#   '0.0'],
#  ['1631220739.24300003',
#   '97270',
#   '0',
#   '0.8810800909996033',
#   ' 0.0',
#   ' 0.0',
#   ' 0.47296714782714844',
#   '-0.08987166732549667',
#   '0.11453802138566971',
#   '-0.00028705739532597363',
#   '0.0'],
#  ['1631220739.90899992',
#   '97901',
#   '0',
#   '0.8816454410552979',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4719124734401703',
#   '-0.09405627846717834',
#   '0.10982836782932281',
#   '-0.0002532032085582614',
#   '0.0'],
#  ['1631220740.32099986',
#   '98532',
#   '0',
#   '0.8821992874145508',
#   ' 0.0',
#   ' 0.0',
#   ' 0.47087618708610535',
#   '-0.09744325280189514',
#   '0.10692797601222992',
#   '-0.0003052639658562839',
#   '0.0'],
#  ['1631220741.01300001',
#   '99154',
#   '0',
#   '0.882703423500061',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4699304699897766',
#   '-0.10036890208721161',
#   '0.10554061830043793',
#   '-0.00030701683135703206',
#   '0.0'],
#  ['1631220741.87500000',
#   '99790',
#   '0',
#   '0.8832067847251892',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4689837396144867',
#   '-0.10313540697097778',
#   '0.1048993244767189',
#   '-0.00031661055982112885',
#   '0.0'],
#  ['1631220742.21000004',
#   '100412',
#   '0',
#   '0.8836838603019714',
#   ' 0.0',
#   ' 0.0',
#   ' 0.46808430552482605',
#   '-0.1056208536028862',
#   '0.10581263154745102',
#   '-0.00034702595439739525',
#   '0.0'],
#  ['1631220742.95199990',
#   '101043',
#   '0',
#   '0.8841673731803894',
#   ' 0.0',
#   ' 0.0',
#   ' 0.46717020869255066',
#   '-0.10826981067657471',
#   '0.10713890194892883',
#   '-0.00035632328945212066',
#   '0.0'],
#  ['1631220743.51099992',
#   '101678',
#   '0',
#   '0.8846631646156311',
#   ' 0.0',
#   ' 0.0',
#   ' 0.46623069047927856',
#   '-0.11022470146417618',
#   '0.10872366279363632',
#   '-0.00034164468524977565',
#   '0.0'],
#  ['1631220744.34200001',
#   '102301',
#   '0',
#   '0.8851243257522583',
#   ' 0.0',
#   ' 0.0',
#   ' 0.46535468101501465',
#   '-0.11174368113279343',
#   '0.11038333922624588',
#   '-0.0003678770153783262',
#   '0.0'],
#  ['1631220745.11399984',
#   '102931',
#   '0',
#   '0.8856018781661987',
#   ' 0.0',
#   ' 0.0',
#   ' 0.46444517374038696',
#   '-0.11238861829042435',
#   '0.11140839755535126',
#   '-0.0003839061828330159',
#   '0.0'],
#  ['1631220745.64499998',
#   '103558',
#   '0',
#   '0.8860403895378113',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4636080861091614',
#   '-0.11253763735294342',
#   '0.11261334270238876',
#   '-0.00038516108179464936',
#   '0.0'],
#  ['1631220746.37800002',
#   '104189',
#   '0',
#   '0.8864603042602539',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4628046452999115',
#   '-0.1130128800868988',
#   '0.11404483765363693',
#   '-0.0003980642359238118',
#   '0.0'],
#  ['1631220746.82799983',
#   '104816',
#   '0',
#   '0.8868969082832336',
#   ' 0.0',
#   ' 0.0',
#   ' 0.46196749806404114',
#   '-0.1131705716252327',
#   '0.11532045155763626',
#   '-0.00040707708103582263',
#   '0.0'],
#  ['1631220747.54099989',
#   '105451',
#   '0',
#   '0.8872594237327576',
#   ' 0.0',
#   ' 0.0',
#   ' 0.46127083897590637',
#   '-0.1136610209941864',
#   '0.11656308174133301',
#   '-0.000398467353079468',
#   '0.0'],
#  ['1631220748.09899998',
#   '106082',
#   '0',
#   '0.8876610398292542',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4604974091053009',
#   '-0.11403317749500275',
#   '0.11774864047765732',
#   '-0.0004186426813248545',
#   '0.0'],
#  ['1631220748.91699982',
#   '106709',
#   '0',
#   '0.8880395293235779',
#   ' 0.0',
#   ' 0.0',
#   ' 0.45976704359054565',
#   '-0.11490488052368164',
#   '0.11828092485666275',
#   '-0.0004099414509255439',
#   '0.0'],
#  ['1631220749.37500000',
#   '107340',
#   '0',
#   '0.888391375541687',
#   ' 0.0',
#   ' 0.0',
#   ' 0.45908692479133606',
#   '-0.11565451323986053',
#   '0.119640052318573',
#   '-0.0004490952705964446',
#   '0.0'],
#  ['1631220749.80499983',
#   '107971',
#   '0',
#   '0.8887433409690857',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4584052264690399',
#   '-0.11643509566783905',
#   '0.12058625370264053',
#   '-0.0004366463399492204',
#   '0.0'],
#  ['1631220750.58299994',
#   '108598',
#   '0',
#   '0.8890852928161621',
#   ' 0.0',
#   ' 0.0',
#   ' 0.45774146914482117',
#   '-0.11786215752363205',
#   '0.12118178606033325',
#   '-0.0004488581034820527',
#   '0.0'],
#  ['1631220751.22899985',
#   '109224',
#   '0',
#   '0.894727349281311',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44661274552345276',
#   '-0.11681617051362991',
#   '0.11912847310304642',
#   '-0.0004448171821422875',
#   '0.0'],
#  ['1631220751.69700003',
#   '109860',
#   '0',
#   '0.8948168754577637',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4464333653450012',
#   '-0.11683600395917892',
#   '0.11701930314302444',
#   '-0.0004750802181661129',
#   '0.0'],
#  ['1631220752.60899997',
#   '110482',
#   '0',
#   '0.8949794769287109',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44610729813575745',
#   '-0.11631224304437637',
#   '0.11554083228111267',
#   '-0.00045902474084869027',
#   '0.0'],
#  ['1631220753.01300001',
#   '111109',
#   '0',
#   '0.8949474096298218',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4461716115474701',
#   '-0.1163078024983406',
#   '0.11500156670808792',
#   '-0.0004580616659950465',
#   '0.0'],
#  ['1631220753.52999997',
#   '111739',
#   '0',
#   '0.8950616717338562',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4459424316883087',
#   '-0.1165504902601242',
#   '0.11472881585359573',
#   '-0.00042929319897666574',
#   '0.0'],
#  ['1631220754.23899984',
#   '112371',
#   '0',
#   '0.895135223865509',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44579461216926575',
#   '-0.11713454127311707',
#   '0.11564638465642929',
#   '-0.00045538495760411024',
#   '0.0'],
#  ['1631220755.08200002',
#   '113002',
#   '0',
#   '0.8951643109321594',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4457363486289978',
#   '-0.1186104416847229',
#   '0.11679898202419281',
#   '-0.0004457934992387891',
#   '0.0'],
#  ['1631220755.44299984',
#   '113628',
#   '0',
#   '0.8952146768569946',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4456351101398468',
#   '-0.11917690187692642',
#   '0.11802371591329575',
#   '-0.00047414767323061824',
#   '0.0'],
#  ['1631220756.42699981',
#   '114259',
#   '0',
#   '0.8952358961105347',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4455925226211548',
#   '-0.12011250853538513',
#   '0.11915140599012375',
#   '-0.00047873574658297',
#   '0.0'],
#  ['1631220756.80499983',
#   '114890',
#   '0',
#   '0.8952723741531372',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44551920890808105',
#   '-0.12108001112937927',
#   '0.11999800056219101',
#   '-0.0004899341147392988',
#   '0.0'],
#  ['1631220757.41999984',
#   '115522',
#   '0',
#   '0.895320475101471',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44542255997657776',
#   '-0.12182207405567169',
#   '0.12004551291465759',
#   '-0.00046798703260719776',
#   '0.0'],
#  ['1631220758.24499989',
#   '116148',
#   '0',
#   '0.8953664302825928',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4453301727771759',
#   '-0.12219411134719849',
#   '0.12053325027227402',
#   '-0.0004583540721796453',
#   '0.0'],
#  ['1631220759.02999997',
#   '116784',
#   '0',
#   '0.8954206705093384',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4452211260795593',
#   '-0.12240660935640335',
#   '0.12114699929952621',
#   '-0.0004907181719318032',
#   '0.0'],
#  ['1631220759.37899995',
#   '117401',
#   '0',
#   '0.8955090641975403',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4450432360172272',
#   '-0.12299422919750214',
#   '0.12121745198965073',
#   '-0.00052520667668432',
#   '0.0'],
#  ['1631220760.23499990',
#   '118032',
#   '0',
#   '0.8954826593399048',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4450964033603668',
#   '-0.12315929681062698',
#   '0.12103879451751709',
#   '-0.0004873572615906596',
#   '0.0'],
#  ['1631220760.69999981',
#   '118663',
#   '0',
#   '0.8955162763595581',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44502872228622437',
#   '-0.12392602115869522',
#   '0.12109100073575974',
#   '-0.0005094163352623582',
#   '0.0'],
#  ['1631220761.08999991',
#   '119290',
#   '0',
#   '0.8955349326133728',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4449911415576935',
#   '-0.12445501983165741',
#   '0.12101060897111893',
#   '-0.0004863778594881296',
#   '0.0'],
#  ['1631220761.87299991',
#   '119921',
#   '0',
#   '0.8955233693122864',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44501450657844543',
#   '-0.12508459389209747',
#   '0.12132339924573898',
#   '-0.000513473292812705',
#   '0.0'],
#  ['1631220762.49599981',
#   '120552',
#   '0',
#   '0.8955588936805725',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4449429214000702',
#   '-0.12538303434848785',
#   '0.12140285968780518',
#   '-0.00048547692131251097',
#   '0.0'],
#  ['1631220762.98399997',
#   '121188',
#   '0',
#   '0.8955927491188049',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4448748230934143',
#   '-0.12586531043052673',
#   '0.12196000665426254',
#   '-0.0005111464415676892',
#   '0.0'],
#  ['1631220763.92400002',
#   '121810',
#   '0',
#   '0.8956382274627686',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44478321075439453',
#   '-0.12558181583881378',
#   '0.12263684719800949',
#   '-0.0005146557814441621',
#   '0.0'],
#  ['1631220764.41199994',
#   '122436',
#   '0',
#   '0.8957014083862305',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44465601444244385',
#   '-0.1257513016462326',
#   '0.12335491180419922',
#   '-0.0005022297264076769',
#   '0.0'],
#  ['1631220765.07999992',
#   '123067',
#   '0',
#   '0.895753800868988',
#   ' 0.0',
#   ' 0.0',
#   ' 0.444550484418869',
#   '-0.12551693618297577',
#   '0.1233777105808258',
#   '-0.0005185022600926459',
#   '0.0'],
#  ['1631220765.77799988',
#   '123820',
#   '0',
#   '0.8957964777946472',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44446438550949097',
#   '-0.12539535760879517',
#   '0.1235884428024292',
#   '-0.000520105822943151',
#   '0.0'],
#  ['1631220766.41999984',
#   '124582',
#   '0',
#   '0.8958325386047363',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44439175724983215',
#   '-0.12510214745998383',
#   '0.12197408825159073',
#   '-0.0004959694342687726',
#   '0.0'],
#  ['1631220767.14199996',
#   '125344',
#   '0',
#   '0.8958359360694885',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44438499212265015',
#   '-0.12624861299991608',
#   '0.12113165855407715',
#   '-0.0005190893425606191',
#   '0.0'],
#  ['1631220768.06099987',
#   '126097',
#   '0',
#   '0.8958443403244019',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44436800479888916',
#   '-0.12662038207054138',
#   '0.12049978226423264',
#   '-0.0005012410692870617',
#   '0.0'],
#  ['1631220768.63499999',
#   '126849',
#   '0',
#   '0.8958699107170105',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44431644678115845',
#   '-0.1280856728553772',
#   '0.12055657058954239',
#   '-0.0005081804702058434',
#   '0.0'],
#  ['1631220769.53499985',
#   '127602',
#   '0',
#   '0.8958880305290222',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44427984952926636',
#   '-0.12889371812343597',
#   '0.12240246683359146',
#   '-0.000521137029863894',
#   '0.0'],
#  ['1631220770.15999985',
#   '128359',
#   '0',
#   '0.8958829641342163',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4442901313304901',
#   '-0.1294402778148651',
#   '0.1233728677034378',
#   '-0.000529688608366996',
#   '0.0'],
#  ['1631220771.07699990',
#   '129121',
#   '0',
#   '0.8958722949028015',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44431161880493164',
#   '-0.1300850510597229',
#   '0.12432129681110382',
#   '-0.0005292643909342587',
#   '0.0'],
#  ['1631220771.77600002',
#   '129870',
#   '0',
#   '0.8959227800369263',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44420984387397766',
#   '-0.13003897666931152',
#   '0.12464319169521332',
#   '-0.0005111657083034515',
#   '0.0'],
#  ['1631220772.70199990',
#   '130627',
#   '0',
#   '0.8959828615188599',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4440886378288269',
#   '-0.13067808747291565',
#   '0.1255967617034912',
#   '-0.0005399914225563407',
#   '0.0'],
#  ['1631220773.22599983',
#   '131380',
#   '0',
#   '0.8959779143333435',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44409865140914917',
#   '-0.13209646940231323',
#   '0.12791728973388672',
#   '-0.0005485230940394104',
#   '0.0'],
#  ['1631220774.03900003',
#   '132142',
#   '0',
#   '0.8960108757019043',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44403207302093506',
#   '-0.13232764601707458',
#   '0.12999938428401947',
#   '-0.0005948747857473791',
#   '0.0'],
#  ['1631220774.70199990',
#   '132903',
#   '0',
#   '0.8960069417953491',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44404006004333496',
#   '-0.1317063271999359',
#   '0.13239556550979614',
#   '-0.0005725709488615394',
#   '0.0'],
#  ['1631220775.50600004',
#   '133651',
#   '0',
#   '0.8960216045379639',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4440104067325592',
#   '-0.13113649189472198',
#   '0.13408780097961426',
#   '-0.0005765134119428694',
#   '0.0'],
#  ['1631220776.23300004',
#   '134404',
#   '0',
#   '0.8960373401641846',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4439787268638611',
#   '-0.13104888796806335',
#   '0.13516463339328766',
#   '-0.0005961599526926875',
#   '0.0'],
#  ['1631220777.00499988',
#   '135166',
#   '0',
#   '0.896013617515564',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44402652978897095',
#   '-0.13085666298866272',
#   '0.13482336699962616',
#   '-0.0005958346882835031',
#   '0.0'],
#  ['1631220777.85200000',
#   '135928',
#   '0',
#   '0.8959941864013672',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44406580924987793',
#   '-0.1302916407585144',
#   '0.13520032167434692',
#   '-0.0005571454530581832',
#   '0.0'],
#  ['1631220778.50799990',
#   '136681',
#   '0',
#   '0.8960082530975342',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4440374970436096',
#   '-0.1306908279657364',
#   '0.13527359068393707',
#   '-0.0005696158041246235',
#   '0.0'],
#  ['1631220779.40599990',
#   '137429',
#   '0',
#   '0.8960111141204834',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44403159618377686',
#   '-0.13053114712238312',
#   '0.13512705266475677',
#   '-0.0006080151069909334',
#   '0.0'],
#  ['1631220780.11800003',
#   '138205',
#   '0',
#   '0.8959817886352539',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44409075379371643',
#   '-0.13114187121391296',
#   '0.1356925517320633',
#   '-0.0005952200735919178',
#   '0.0'],
#  ['1631220780.96700001',
#   '138948',
#   '0',
#   '0.8959448337554932',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4441654086112976',
#   '-0.13143552839756012',
#   '0.13651122152805328',
#   '-0.0005971454083919525',
#   '0.0'],
#  ['1631220781.63299990',
#   '139701',
#   '0',
#   '0.8959418535232544',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4441714286804199',
#   '-0.13162685930728912',
#   '0.136776402592659',
#   '-0.0006080837338231504',
#   '0.0'],
#  ['1631220782.40199995',
#   '140458',
#   '0',
#   '0.8959406018257141',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4441738724708557',
#   '-0.13271716237068176',
#   '0.1369553804397583',
#   '-0.0006119458703324199',
#   '0.0'],
#  ['1631220783.08200002',
#   '141211',
#   '0',
#   '0.895939826965332',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4441753923892975',
#   '-0.13289585709571838',
#   '0.1362425684928894',
#   '-0.0005858492804691195',
#   '0.0'],
#  ['1631220783.84999990',
#   '141968',
#   '0',
#   '0.8959188461303711',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4442176818847656',
#   '-0.132638081908226',
#   '0.13519656658172607',
#   '-0.0005980133428238332',
#   '0.0'],
#  ['1631220784.70299983',
#   '142730',
#   '0',
#   '0.8958832621574402',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44428956508636475',
#   '-0.13233137130737305',
#   '0.13532370328903198',
#   '-0.0005872207111679018',
#   '0.0'],
#  ['1631220785.32499981',
#   '143483',
#   '0',
#   '0.8958683013916016',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4443196654319763',
#   '-0.13220980763435364',
#   '0.13464640080928802',
#   '-0.0005776876350864768',
#   '0.0'],
#  ['1631220786.09999990',
#   '144240',
#   '0',
#   '0.8958632349967957',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4443298876285553',
#   '-0.132162407040596',
#   '0.13339999318122864',
#   '-0.0005840230151079595',
#   '0.0'],
#  ['1631220786.99399996',
#   '144993',
#   '0',
#   '0.8958998918533325',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44425591826438904',
#   '-0.13194698095321655',
#   '0.13250716030597687',
#   '-0.0005918477545492351',
#   '0.0'],
#  ['1631220787.70499992',
#   '145750',
#   '0',
#   '0.8959137797355652',
#   ' 0.0',
#   ' 0.0',
#   ' 0.44422799348831177',
#   '-0.13193130493164062',
#   '0.13159148395061493',
#   '-0.0005806484841741621',
#   '0.0'],
#  ['1631220788.51499987',
#   '146503',
#   '0',
#   '0.8965125679969788',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4430183172225952',
#   '-0.12504293024539948',
#   '0.09960628300905228',
#   '0.00013251732161734253',
#   '0.0'],
#  ['1631220848.36399984',
#   '13332',
#   '0',
#   '0.9096792936325073',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4153115153312683',
#   '0.41717082262039185',
#   '0.31987079977989197',
#   '0.00442170025780797',
#   '0.0'],
#  ['1631220848.81399989',
#   '13963',
#   '0',
#   '0.909912645816803',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4148000180721283',
#   '0.41491061449050903',
#   '0.31393977999687195',
#   '0.004228753037750721',
#   '0.0'],
#  ['1631220849.52499986',
#   '14595',
#   '0',
#   '0.9096543192863464',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41536617279052734',
#   '0.4114639461040497',
#   '0.30815592408180237',
#   '0.0041901059448719025',
#   '0.0'],
#  ['1631220850.09399986',
#   '15221',
#   '0',
#   '0.9093055725097656',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41612908244132996',
#   '0.3987998962402344',
#   '0.2987775206565857',
#   '0.003945335280150175',
#   '0.0'],
#  ['1631220850.75199986',
#   '15848',
#   '0',
#   '0.9090971946716309',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4165841341018677',
#   '0.3856337368488312',
#   '0.29004597663879395',
#   '0.003720489563420415',
#   '0.0'],
#  ['1631220851.32799983',
#   '16474',
#   '0',
#   '0.908944845199585',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4169164299964905',
#   '0.3745097517967224',
#   '0.28293636441230774',
#   '0.003487328067421913',
#   '0.0'],
#  ['1631220852.10899997',
#   '17110',
#   '0',
#   '0.9087263345718384',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41739240288734436',
#   '0.3654263913631439',
#   '0.2770915925502777',
#   '0.0033426573500037193',
#   '0.0'],
#  ['1631220852.50699997',
#   '17741',
#   '0',
#   '0.908562958240509',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4177478551864624',
#   '0.3572993278503418',
#   '0.2720218300819397',
#   '0.0031960380729287863',
#   '0.0'],
#  ['1631220853.29299998',
#   '18363',
#   '0',
#   '0.9083993434906006',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41810357570648193',
#   '0.3488069474697113',
#   '0.26714518666267395',
#   '0.003065985394641757',
#   '0.0'],
#  ['1631220853.81299996',
#   '19003',
#   '0',
#   '0.9083544015884399',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4182012677192688',
#   '0.340254008769989',
#   '0.2631188929080963',
#   '0.0029629054479300976',
#   '0.0'],
#  ['1631220854.50600004',
#   '19620',
#   '0',
#   '0.9082668423652649',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4183914363384247',
#   '0.33268415927886963',
#   '0.25945737957954407',
#   '0.002828152384608984',
#   '0.0'],
#  ['1631220855.00600004',
#   '20251',
#   '0',
#   '0.9081810116767883',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41857773065567017',
#   '0.3250788152217865',
#   '0.2563488781452179',
#   '0.0027510153595358133',
#   '0.0'],
#  ['1631220855.80299997',
#   '20883',
#   '0',
#   '0.9081968069076538',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41854342818260193',
#   '0.3182128071784973',
#   '0.25421568751335144',
#   '0.0026764560025185347',
#   '0.0'],
#  ['1631220856.25899982',
#   '21513',
#   '0',
#   '0.9081740379333496',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4185928702354431',
#   '0.3121850788593292',
#   '0.25221776962280273',
#   '0.0025828606449067593',
#   '0.0'],
#  ['1631220857.09099984',
#   '22140',
#   '0',
#   '0.908129096031189',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4186902940273285',
#   '0.30624809861183167',
#   '0.25085994601249695',
#   '0.0025604753755033016',
#   '0.0'],
#  ['1631220857.51499987',
#   '22771',
#   '0',
#   '0.9081572890281677',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41862913966178894',
#   '0.3007415533065796',
#   '0.250223845243454',
#   '0.0025170687586069107',
#   '0.0'],
#  ['1631220858.32999992',
#   '23402',
#   '0',
#   '0.9082076549530029',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41851985454559326',
#   '0.29617080092430115',
#   '0.2496050000190735',
#   '0.002444945042952895',
#   '0.0'],
#  ['1631220858.93400002',
#   '24034',
#   '0',
#   '0.9082286953926086',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4184741675853729',
#   '0.2925308346748352',
#   '0.24936774373054504',
#   '0.002417314099147916',
#   '0.0'],
#  ['1631220859.59799981',
#   '24664',
#   '0',
#   '0.9082454442977905',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4184378385543823',
#   '0.2897799015045166',
#   '0.24933616816997528',
#   '0.0023846926633268595',
#   '0.0'],
#  ['1631220860.09399986',
#   '25295',
#   '0',
#   '0.908244788646698',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41843923926353455',
#   '0.28775376081466675',
#   '0.24895182251930237',
#   '0.002361697144806385',
#   '0.0'],
#  ['1631220861.10200000',
#   '25922',
#   '0',
#   '0.9083545804023743',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4182007908821106',
#   '0.28619101643562317',
#   '0.2487909197807312',
#   '0.0023629837669432163',
#   '0.0'],
#  ['1631220861.67999983',
#   '26553',
#   '0',
#   '0.9084218740463257',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41805461049079895',
#   '0.28401151299476624',
#   '0.24784795939922333',
#   '0.0023252542596310377',
#   '0.0'],
#  ['1631220862.13199997',
#   '27175',
#   '0',
#   '0.9083516001701355',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4182072579860687',
#   '0.28144484758377075',
#   '0.24683819711208344',
#   '0.0022908076643943787',
#   '0.0'],
#  ['1631220862.66400003',
#   '27811',
#   '0',
#   '0.9083975553512573',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4181075096130371',
#   '0.2792021632194519',
#   '0.24622946977615356',
#   '0.00229638465680182',
#   '0.0'],
#  ['1631220863.83699989',
#   '28433',
#   '0',
#   '0.9084544777870178',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41798385977745056',
#   '0.27774980664253235',
#   '0.24584174156188965',
#   '0.0022733828518539667',
#   '0.0'],
#  ['1631220864.02499986',
#   '29068',
#   '0',
#   '0.9085068702697754',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4178699553012848',
#   '0.27729177474975586',
#   '0.24553027749061584',
#   '0.0022626607678830624',
#   '0.0'],
#  ['1631220864.64199996',
#   '29695',
#   '0',
#   '0.9085325002670288',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4178142249584198',
#   '0.276740163564682',
#   '0.2454100251197815',
#   '0.002226197626441717',
#   '0.0'],
#  ['1631220865.07099986',
#   '30321',
#   '0',
#   '0.9085279107093811',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4178241789340973',
#   '0.27616938948631287',
#   '0.24522216618061066',
#   '0.002255859784781933',
#   '0.0'],
#  ['1631220866.00899982',
#   '30953',
#   '0',
#   '0.9085794687271118',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41771200299263',
#   '0.27573785185813904',
#   '0.24521999061107635',
#   '0.002247551688924432',
#   '0.0'],
#  ['1631220866.31999993',
#   '31584',
#   '0',
#   '0.908625602722168',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41761162877082825',
#   '0.275336891412735',
#   '0.24589276313781738',
#   '0.0022475020959973335',
#   '0.0'],
#  ['1631220867.07099986',
#   '32210',
#   '0',
#   '0.9086943864822388',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41746196150779724',
#   '0.27538639307022095',
#   '0.2457170933485031',
#   '0.0022502325009554625',
#   '0.0'],
#  ['1631220867.63499999',
#   '32841',
#   '0',
#   '0.908715009689331',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41741713881492615',
#   '0.2747932970523834',
#   '0.24524115025997162',
#   '0.0022347804624587297',
#   '0.0'],
#  ['1631220868.33099985',
#   '33468',
#   '0',
#   '0.9087787866592407',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4172782301902771',
#   '0.27411404252052307',
#   '0.24553117156028748',
#   '0.0022286835592240095',
#   '0.0'],
#  ['1631220868.97000003',
#   '34103',
#   '0',
#   '0.9088482856750488',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41712674498558044',
#   '0.2734220325946808',
#   '0.24508267641067505',
#   '0.0022382785100489855',
#   '0.0'],
#  ['1631220869.80199981',
#   '34730',
#   '0',
#   '0.9089412689208984',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4169241189956665',
#   '0.2727176547050476',
#   '0.2445646971464157',
#   '0.002204669639468193',
#   '0.0'],
#  ['1631220870.21199989',
#   '35365',
#   '0',
#   '0.9089785218238831',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4168430268764496',
#   '0.2722093462944031',
#   '0.24450251460075378',
#   '0.0022111497819423676',
#   '0.0'],
#  ['1631220871.03399992',
#   '35983',
#   '0',
#   '0.9090015888214111',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41679275035858154',
#   '0.27253326773643494',
#   '0.24464109539985657',
#   '0.0022229196038097143',
#   '0.0'],
#  ['1631220871.54799986',
#   '36614',
#   '0',
#   '0.9089235663414001',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41696280241012573',
#   '0.27250218391418457',
#   '0.24438518285751343',
#   '0.0022087888792157173',
#   '0.0'],
#  ['1631220872.71799994',
#   '37250',
#   '0',
#   '0.9089583158493042',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4168870151042938',
#   '0.2722521722316742',
#   '0.24438665807247162',
#   '0.0022089038975536823',
#   '0.0'],
#  ['1631220873.03299999',
#   '37881',
#   '0',
#   '0.9089577794075012',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41688817739486694',
#   '0.27201923727989197',
#   '0.2446044683456421',
#   '0.0022301836870610714',
#   '0.0'],
#  ['1631220873.86999989',
#   '38503',
#   '0',
#   '0.9089443683624268',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4169173538684845',
#   '0.27214521169662476',
#   '0.2445000261068344',
#   '0.0021816145163029432',
#   '0.0'],
#  ['1631220874.10299993',
#   '39134',
#   '0',
#   '0.9089500308036804',
#   ' 0.0',
#   ' 0.0',
#   ' 0.416905015707016',
#   '0.2714863419532776',
#   '0.24464154243469238',
#   '0.0022069127298891544',
#   '0.0'],
#  ['1631220874.65699983',
#   '39891',
#   '0',
#   '0.9090040922164917',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41678711771965027',
#   '0.2709936797618866',
#   '0.24403731524944305',
#   '0.0022099183406680822',
#   '0.0'],
#  ['1631220875.81099987',
#   '40644',
#   '0',
#   '0.9090625047683716',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4166598320007324',
#   '0.2682206332683563',
#   '0.2430408000946045',
#   '0.0021541728638112545',
#   '0.0'],
#  ['1631220876.24799991',
#   '41406',
#   '0',
#   '0.9090647101402283',
#   ' 0.0',
#   ' 0.0',
#   ' 0.416655033826828',
#   '0.2693175971508026',
#   '0.24203065037727356',
#   '0.0021677324548363686',
#   '0.0'],
#  ['1631220877.14699984',
#   '42159',
#   '0',
#   '0.9090458154678345',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41669613122940063',
#   '0.26894453167915344',
#   '0.24086377024650574',
#   '0.002137888688594103',
#   '0.0'],
#  ['1631220877.80599999',
#   '42912',
#   '0',
#   '0.9090864062309265',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41660764813423157',
#   '0.26927629113197327',
#   '0.2430134266614914',
#   '0.0021920031867921352',
#   '0.0'],
#  ['1631220878.43799996',
#   '43669',
#   '0',
#   '0.9090849757194519',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4166107773780823',
#   '0.26855069398880005',
#   '0.24192066490650177',
#   '0.00216109910979867',
#   '0.0'],
#  ['1631220879.28699994',
#   '44422',
#   '0',
#   '0.9090791344642639',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41662347316741943',
#   '0.26978325843811035',
#   '0.2401486486196518',
#   '0.002153117675334215',
#   '0.0'],
#  ['1631220880.05199981',
#   '45183',
#   '0',
#   '0.9091095328330994',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4165571331977844',
#   '0.2699842154979706',
#   '0.24082134664058685',
#   '0.002155945636332035',
#   '0.26923078298568726'],
#  ['1631220880.80199981',
#   '45941',
#   '0',
#   '0.9091405868530273',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4164893329143524',
#   '0.2694452404975891',
#   '0.239343523979187',
#   '0.0021394684445112944',
#   '0.0'],
#  ['1631220881.63899994',
#   '46693',
#   '0',
#   '0.9091905355453491',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4163803160190582',
#   '0.2689470946788788',
#   '0.2385706752538681',
#   '0.0021375413052737713',
#   '0.0'],
#  ['1631220882.27399993',
#   '47451',
#   '0',
#   '0.9091935753822327',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41637367010116577',
#   '0.2671653628349304',
#   '0.23815685510635376',
#   '0.002109736669808626',
#   '0.0'],
#  ['1631220883.03600001',
#   '48249',
#   '0',
#   '0.9091398119926453',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4164911210536957',
#   '0.268991619348526',
#   '0.23859871923923492',
#   '0.002134214621037245',
#   '0.0010000000474974513'],
#  ['1631220884.05999994',
#   '49038',
#   '0',
#   '0.9090847969055176',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41661110520362854',
#   '0.2679014503955841',
#   '0.2382175326347351',
#   '0.002110657747834921',
#   '0.0010000000474974513'],
#  ['1631220884.80799985',
#   '49842',
#   '0',
#   '0.9088916182518005',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41703251004219055',
#   '0.26873713731765747',
#   '0.23957540094852448',
#   '0.0024041025899350643',
#   '0.0010000000474974513'],
#  ['1631220885.39999986',
#   '50639',
#   '0',
#   '0.9077963829040527',
#   ' 0.0',
#   ' 0.0',
#   ' 0.41941118240356445',
#   '0.27195194363594055',
#   '0.23594409227371216',
#   '0.00045771553413942456',
#   '0.0010000000474974513'],
#  ['1631220886.21899986',
#   '51441',
#   '0',
#   '0.9066859483718872',
#   ' 0.0',
#   ' 0.0',
#   ' 0.42180636525154114',
#   '0.2779213786125183',
#   '0.24187158048152924',
#   '0.0020842761732637882',
#   '0.0010000000474974513'],
#  ['1631220887.01399994',
#   '52231',
#   '0',
#   '0.9058048129081726',
#   ' 0.0',
#   ' 0.0',
#   ' 0.42369526624679565',
#   '0.27752870321273804',
#   '0.24674540758132935',
#   '0.0008664203924126923',
#   '0.0010000000474974513'],
#  ['1631220888.13499999',
#   '53029',
#   '0',
#   '0.9050968289375305',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4252055287361145',
#   '0.2790568768978119',
#   '0.2429628074169159',
#   '0.0029820126947015524',
#   '0.0010000000474974513'],
#  ['1631220888.66199994',
#   '53831',
#   '0',
#   '0.9045569896697998',
#   ' 0.0',
#   ' 0.0',
#   ' 0.42635273933410645',
#   '0.2746189832687378',
#   '0.24353641271591187',
#   '-0.001615538029000163',
#   '0.14480887353420258'],
#  ['1631220889.49000001',
#   '54630',
#   '0',
#   '0.9045569896697998',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4263527989387512',
#   '0.26666882634162903',
#   '0.22659114003181458',
#   '-0.012246182188391685',
#   '0.2965709865093231'],
#  ['1631220890.24499989',
#   '55423',
#   '0',
#   '0.9045569896697998',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4263527989387512',
#   '0.06722772121429443',
#   '-0.1000140979886055',
#   '-0.01950257644057274',
#   '0.4461267292499542'],
#  ['1631220891.27199984',
#   '56220',
#   '0',
#   '0.9044862985610962',
#   ' 0.005329977720975876',
#   ' -0.011308171786367893',
#   ' 0.4263194501399994',
#   '-0.014185847714543343',
#   '-0.33344343304634094',
#   '-0.029161572456359863',
#   '0.464754194021225'],
#  ['1631220892.30699992',
#   '57017',
#   '0',
#   '0.9045201539993286',
#   ' 0.0038499231450259686',
#   ' -0.008168061263859272',
#   ' 0.42633530497550964',
#   '-0.11860687285661697',
#   '-0.05382397025823593',
#   '-0.013474718667566776',
#   '0.553681492805481'],
#  ['1631220892.94700003',
#   '57820',
#   '0',
#   '0.9043116569519043',
#   ' -0.020705748349428177',
#   ' -0.015133045613765717',
#   ' 0.4261016845703125',
#   '-0.2879680097103119',
#   '0.02391950413584709',
#   '-0.008292606100440025',
#   '0.5308758020401001'],
#  ['1631220893.43499994',
#   '58618',
#   '0',
#   '0.9045283198356628',
#   ' -0.002778578083962202',
#   ' -0.010523485951125622',
#   ' 0.42627471685409546',
#   '-0.13054503500461578',
#   '-0.02574896812438965',
#   '-0.016433538869023323',
#   '0.4538224935531616'],
#  ['1631220894.23499990',
#   '59411',
#   '0',
#   '0.9042858481407166',
#   ' -0.022148413583636284',
#   ' -0.010439402423799038',
#   ' 0.42622482776641846',
#   '-0.13968941569328308',
#   '-0.1351432204246521',
#   '-0.009573426097631454',
#   '0.5659977197647095'],
#  ['1631220895.07699990',
#   '60209',
#   '0',
#   '0.8836718201637268',
#   ' -0.01608218438923359',
#   ' -0.008512765169143677',
#   ' 0.4677530825138092',
#   '0.082131028175354',
#   '-0.04512365907430649',
#   '0.002667168155312538',
#   '0.5320418477058411'],
#  ['1631220895.96199989',
#   '61002',
#   '0',
#   '0.8838182091712952',
#   ' 0.0',
#   ' 0.0',
#   ' 0.46783047914505005',
#   '-0.118751659989357',
#   '-0.058979302644729614',
#   '0.004270982928574085',
#   '0.5357108116149902'],
#  ['1631220896.69099998',
#   '61800',
#   '0',
#   '0.883543848991394',
#   ' -0.021866803988814354',
#   ' -0.015503129921853542',
#   ' 0.4675808250904083',
#   '-0.38420334458351135',
#   '-0.025203347206115723',
#   '0.000547948235180229',
#   '0.5279736518859863'],
#  ['1631220897.44099998',
#   '62598',
#   '0',
#   '0.883682906627655',
#   ' -0.015464525669813156',
#   ' -0.00818581972271204',
#   ' 0.4677588939666748',
#   '-0.11931458860635757',
#   '-0.06524112820625305',
#   '-0.0011980971321463585',
#   '0.5414340496063232'],
#  ['1631220898.29600000',
#   '63401',
#   '0',
#   '0.8825107216835022',
#   ' -0.04805630445480347',
#   ' -0.02543758973479271',
#   ' 0.4671383798122406',
#   '-0.1240069568157196',
#   '-0.027022704482078552',
#   '9.127091470872983e-05',
#   '0.5268663167953491'],
#  ['1631220899.00799990',
#   '64198',
#   '0',
#   '0.8783255219459534',
#   ' -0.0983816459774971',
#   ' -0.052076246589422226',
#   ' 0.46492302417755127',
#   '-0.20794564485549927',
#   '-0.03539275377988815',
#   '-0.016134250909090042',
#   '0.5296492576599121'],
#  ['1631220899.92299986',
#   '64987',
#   '0',
#   '0.8817639350891113',
#   ' -0.06022469326853752',
#   ' -0.03187866136431694',
#   ' 0.466743141412735',
#   '-0.13234418630599976',
#   '-0.002651177579537034',
#   '0.005751045886427164',
#   '0.4498916268348694'],
#  ['1631220900.81900001',
#   '65798',
#   '0',
#   '0.8821201324462891',
#   ' -0.05476055294275284',
#   ' -0.028986334800720215',
#   ' 0.46693161129951477',
#   '-0.7209701538085938',
#   '-0.07238088548183441',
#   '-0.004195281304419041',
#   '0.5284467339515686'],
#  ['1631220901.36599994',
#   '66588',
#   '0',
#   '0.8796805143356323',
#   ' -0.08542110025882721',
#   ' -0.04521586745977402',
#   ' 0.46564027667045593',
#   '-0.6027292013168335',
#   '-0.11357845366001129',
#   '-0.025263339281082153',
#   '0.5273858904838562'],
#  ['1631220903.80799985',
#   '68178',
#   '0',
#   '0.8817639350891113',
#   ' -0.060224685817956924',
#   ' -0.03187866136431694',
#   ' 0.466743141412735',
#   '-0.6904510855674744',
#   '-0.04499441385269165',
#   '0.00023653623065911233',
#   '0.5323127508163452'],
#  ['1631220903.80900002',
#   '68981',
#   '0',
#   '0.882339358329773',
#   ' -0.0511070117354393',
#   ' -0.027052419260144234',
#   ' 0.46704763174057007',
#   '-0.491738885641098',
#   '-0.061030007898807526',
#   '0.006440259050577879',
#   '0.5202036499977112'],
#  ['1631220904.57099986',
#   '69779',
#   '0',
#   '0.881464421749115',
#   ' -0.0644601583480835',
#   ' -0.034120623022317886',
#   ' 0.46658456325531006',
#   '-0.4524264335632324',
#   '-0.018246185034513474',
#   '0.004755116067826748',
#   '0.5277013182640076'],
#  ['1631220905.39800000',
#   '70582',
#   '0',
#   '0.8801293969154358',
#   ' -0.08066470175981522',
#   ' -0.04269815981388092',
#   ' 0.4658779501914978',
#   '-0.8560069799423218',
#   '-0.05323141813278198',
#   '0.012137850746512413',
#   '0.5259841680526733'],
#  ['1631220906.47799993',
#   '71379',
#   '0',
#   '0.8810029625892639',
#   ' -0.07048743218183517',
#   ' -0.03731103241443634',
#   ' 0.4663403034210205',
#   '-0.5026009678840637',
#   '-0.10297123342752457',
#   '-0.0007952590240165591',
#   '0.5330073237419128'],
#  ['1631220907.58399987',
#   '72168',
#   '0',
#   '0.8818289637565613',
#   ' -0.0592077374458313',
#   ' -0.035260800272226334',
#   ' 0.46650704741477966',
#   '-0.592786431312561',
#   '-0.01127821858972311',
#   '-0.01361234299838543',
#   '0.5291635394096375'],
#  ['1631220908.09299994',
#   '72971',
#   '0',
#   '0.8823744058609009',
#   ' -0.050497330725193024',
#   ' -0.02672969363629818',
#   ' 0.4670662581920624',
#   '-0.46070417761802673',
#   '-0.06370820105075836',
#   '0.0005880906246602535',
#   '0.5338429808616638'],
#  ['1631220908.97199988',
#   '73773',
#   '0',
#   '0.8802419304847717',
#   ' -0.07942096143960953',
#   ' -0.0436052642762661',
#   ' 0.4657950699329376',
#   '-0.9110464453697205',
#   '-0.0264568030834198',
#   '-0.00722475815564394',
#   '0.5400769114494324'],
#  ['1631220909.42599988',
#   '74558',
#   '0',
#   '0.883016049861908',
#   ' -0.037647489458322525',
#   ' -0.019927900284528732',
#   ' 0.46740588545799255',
#   '-0.21690061688423157',
#   '-0.051968857645988464',
#   '0.0013130215229466558',
#   '0.5260282158851624'],
#  ['1631220910.11299992',
#   '75359',
#   '0',
#   '0.8791624903678894',
#   ' -0.09044759720563889',
#   ' -0.05569133162498474',
#   ' 0.46453309059143066',
#   '-0.8398409485816956',
#   '-0.08704493939876556',
#   '-0.00011105547309853137',
#   '0.55202716588974'],
#  ['1631220910.91699982',
#   '76157',
#   '0',
#   '0.8808107376098633',
#   ' -0.07284224033355713',
#   ' -0.040123991668224335',
#   ' 0.4661078453063965',
#   '-0.6087242364883423',
#   '-0.011211575008928776',
#   '0.014123890548944473',
#   '0.5336547493934631'],
#  ['1631220911.70299983',
#   '76960',
#   '0',
#   '0.8821576237678528',
#   ' -0.0541522391140461',
#   ' -0.028664343059062958',
#   ' 0.46695151925086975',
#   '-0.022760091349482536',
#   '0.055277515202760696',
#   '0.019896792247891426',
#   '0.524648129940033'],
#  ['1631220912.65999985',
#   '77758',
#   '0',
#   '0.8838182091712952',
#   ' 0.0',
#   ' 0.0',
#   ' 0.46783050894737244',
#   '-0.5240623950958252',
#   '-0.09452081471681595',
#   '0.01391639094799757',
#   '0.5430827736854553'],
#  ['1631220913.42499995',
#   '78560',
#   '0',
#   '0.8834248781204224',
#   ' 0.013955451548099518',
#   ' -0.02636442705988884',
#   ' 0.467622309923172',
#   '-0.09711100906133652',
#   '0.04234090819954872',
#   '0.015431322157382965',
#   '0.5575581192970276'],
#  ['1631220914.23399997',
#   '79349',
#   '0',
#   '0.8817136883735657',
#   ' 0.032265596091747284',
#   ' -0.060955654829740524',
#   ' 0.46671655774116516',
#   '-0.0267123281955719',
#   '-0.2545456886291504',
#   '-0.00245360704138875',
#   '0.5421121120452881'],
#  ['1631220915.26399994',
#   '80148',
#   '0',
#   '0.8805025219917297',
#   ' 0.040485821664333344',
#   ' -0.07648518681526184',
#   ' 0.46607545018196106',
#   '0.005161341745406389',
#   '-0.0963473692536354',
#   '-0.018936188891530037',
#   '0.5483095049858093'],
#  ['1631220915.83500004',
#   '80940',
#   '0',
#   '0.8809028267860413',
#   ' 0.03796755149960518',
#   ' -0.07172772288322449',
#   ' 0.4662873446941376',
#   '-0.04046439006924629',
#   '-0.6470290422439575',
#   '-0.0679619312286377',
#   '0.5451200604438782'],
#  ['1631220916.58500004',
#   '81739',
#   '0',
#   '0.8819558620452881',
#   ' 0.030354712158441544',
#   ' -0.057345662266016006',
#   ' 0.4668446481227875',
#   '-0.09136287122964859',
#   '-0.6993711590766907',
#   '-0.0384620800614357',
#   '0.5470149517059326'],
#  ['1631220917.28499985',
#   '82540',
#   '0',
#   '0.8823275566101074',
#   ' 0.027159983292222023',
#   ' -0.0513102263212204',
#   ' 0.4670414924621582',
#   '0.014499122276902199',
#   '-0.6916021108627319',
#   '0.03830421343445778',
#   '0.5252088308334351'],
#  ['1631220918.08799982',
#   '83338',
#   '0',
#   '0.8812379837036133',
#   ' 0.03395021706819534',
#   ' -0.07003464549779892',
#   ' 0.4662211835384369',
#   '0.09780588746070862',
#   '-0.6103785037994385',
#   '0.014764041639864445',
#   '0.5220943093299866'],
#  ['1631220919.07699990',
#   '84127',
#   '0',
#   '0.8816298246383667',
#   ' 0.032901372760534286',
#   ' -0.06215676665306091',
#   ' 0.4666721820831299',
#   '0.06584928184747696',
#   '-0.5214043259620667',
#   '-0.024158906191587448',
#   '0.5307625532150269'],
#  ['1631220919.80399990',
#   '84930',
#   '0',
#   '0.8801864385604858',
#   ' 0.042367760092020035',
#   ' -0.08004051446914673',
#   ' 0.46590811014175415',
#   '0.06768326461315155',
#   '-0.8321454524993896',
#   '-0.025248119607567787',
#   '0.5347809195518494'],
#  ['1631220920.64399981',
#   '85728',
#   '0',
#   '0.880078136920929',
#   ' 0.04299357905983925',
#   ' -0.08122280985116959',
#   ' 0.4658508002758026',
#   '0.05815388262271881',
#   '-0.6215347051620483',
#   '-0.03100881539285183',
#   '0.5230764746665955'],
#  ['1631220921.38699985',
#   '86530',
#   '0',
#   '0.8827871084213257',
#   ' -0.042361509054899216',
#   ' -0.03027178719639778',
#   ' 0.46687912940979004',
#   '0.1574627012014389',
#   '-0.4010331928730011',
#   '-7.359973096754402e-05',
#   '0.535910427570343'],
#  ['1631220922.30799985',
#   '87319',
#   '0',
#   '0.8831123113632202',
#   ' -0.033224888145923615',
#   ' -0.03563804551959038',
#   ' 0.46662476658821106',
#   '-0.08210261166095734',
#   '-0.5203003287315369',
#   '0.011882252059876919',
#   '0.5374642610549927'],
#  ['1631220923.03299999',
#   '88122',
#   '0',
#   '0.8799439668655396',
#   ' -0.08238567411899567',
#   ' -0.053776271641254425',
#   ' 0.46477872133255005',
#   '-0.06860605627298355',
#   '-0.3140629529953003',
#   '0.0127188665792346',
#   '0.5520752668380737'],
#  ['1631220923.90999985',
#   '88919',
#   '0',
#   '0.8808935284614563',
#   ' -0.07122769206762314',
#   ' -0.05179305374622345',
#   ' 0.465049147605896',
#   '-0.34241753816604614',
#   '-0.11168959736824036',
#   '0.03118603117763996',
#   '0.5436118245124817'],
#  ['1631220924.64100003',
#   '89717',
#   '0',
#   '0.8838182091712952',
#   ' 0.0',
#   ' 0.0',
#   ' 0.46783050894737244',
#   '-0.32689768075942993',
#   '0.15740200877189636',
#   '-0.03581415116786957',
#   '0.5555228590965271'],
#  ['1631220925.30199981',
#   '90510',
#   '0',
#   '0.8838182091712952',
#   ' 0.0',
#   ' 0.0',
#   ' 0.46783050894737244',
#   '-0.35826388001441956',
#   '0.14815829694271088',
#   '0.006105606444180012',
#   '0.5635262131690979'],
#  ['1631220926.17199993',
#   '91317',
#   '0',
#   '0.8831040859222412',
#   ' 0.01880309171974659',
#   ' -0.03552251309156418',
#   ' 0.4674524962902069',
#   '-0.6702560186386108',
#   '0.08983336389064789',
#   '-0.05932196229696274',
#   '0.5467459559440613'],
#  ['1631220926.94599986',
#   '92115',
#   '0',
#   '0.8765807151794434',
#   ' -0.11287524551153183',
#   ' -0.05974813923239708',
#   ' 0.463999480009079',
#   '-0.5134598612785339',
#   '-0.07576411962509155',
#   '0.0773090124130249',
#   '0.555047869682312'],
#  ['1631220927.83799982',
#   '92909',
#   '0',
#   '0.8815951347351074',
#   ' -0.06264658272266388',
#   ' -0.033160656690597534',
#   ' 0.4666537940502167',
#   '-0.31580060720443726',
#   '-0.009716871194541454',
#   '0.07364100962877274',
#   '0.5402575135231018'],
#  ['1631220928.75999999',
#   '93698',
#   '0',
#   '0.8816803693771362',
#   ' -0.061436109244823456',
#   ' -0.032519903033971786',
#   ' 0.4666987955570221',
#   '-0.4796718955039978',
#   '0.06357815116643906',
#   '0.0003090424579568207',
#   '0.5391560792922974'],
#  ['1631220929.37299991',
#   '94500',
#   '0',
#   '0.8823744654655457',
#   ' -0.05049732327461243',
#   ' -0.026729688048362732',
#   ' 0.4670662581920624',
#   '-0.5659415125846863',
#   '0.08878780901432037',
#   '0.06566335260868073',
#   '0.5517873764038086'],
#  ['1631220930.17299986',
#   '95303',
#   '0',
#   '0.9083979725837708',
#   ' -0.05576302111148834',
#   ' -0.02538886107504368',
#   ' 0.4135928153991699',
#   '-0.09062033146619797',
#   '-0.3908821940422058',
#   '0.008537651970982552',
#   '0.547928512096405'],
#  ['1631220930.87199998',
#   '96100',
#   '0',
#   '0.908003568649292',
#   ' 0.0',
#   ' 0.0',
#   ' 0.4189624786376953',
#   '-0.25446146726608276',
#   '-0.009979462251067162',
#   '0.17925621569156647',
#   '0.5549716949462891'],
#  ['1631220931.75499988',
#   '96898',
#   '0',
#   '0.8605887293815613',
#   ' 0.0',
#   ' 0.0',
#   ' 0.5093005895614624',
#   '-0.0702342689037323',
#   '0.13669583201408386',
#   '0.528436005115509',
#   '0.5535973310470581'],
#  ['1631220932.53199983',
#   '97687',
#   '0',
#   '0.7878854274749756',
#   ' 0.0',
#   ' 0.0',
#   ' 0.6158219575881958',
#   '-0.05986764281988144',
#   '0.29943230748176575',
#   '0.19966530799865723',
#   '0.5498091578483582'],
#  ['1631220933.36699986',
#   '98494',
#   '0',
#   '0.72190922498703',
#   ' 0.0067287771962583065',
#   ' -0.0070204222574830055',
#   ' 0.6919194459915161',
#   '-0.05132623761892319',
#   '0.1831722855567932',
#   '0.15142005681991577',
#   '0.5400981903076172'],
#  ['1631220934.30599999',
#   '99292',
#   '0',
#   '0.6666926145553589',
#   ' 0.010351291857659817',
#   ' -0.009260733611881733',
#   ' 0.7452033758163452',
#   '-0.07879363745450974',
#   '0.1383124738931656',
#   '0.006575418636202812',
#   '0.5434337258338928'],
#  ['1631220934.89899993',
#   '100085',
#   '0',
#   '0.6624543070793152',
#   ' 0.0',
#   ' 0.0',
#   ' 0.7491023540496826',
#   '0.15486587584018707',
#   '-0.09420517086982727',
#   '-0.015161522664129734',
#   '0.5461458563804626'],
#  ['1631220935.70700002',
#   '100888',
#   '0',
#   '0.6595216393470764',
#   ' 0.005219663493335247',
#   ' -0.004579877480864525',
#   ' 0.7516534924507141',
#   '0.0773327648639679',
#   '-0.26066869497299194',
#   '0.017631426453590393',
#   '0.5463008284568787'],
#  ['1631220936.66599989',
#   '101681',
#   '0',
#   '0.6434961557388306',
#   ' 0.0',
#   ' 0.0',
#   ' 0.7654494047164917',
#   '0.20153695344924927',
#   '-0.03401484340429306',
#   '0.12997157871723175',
#   '0.5500853657722473'],
#  ['1631220937.28900003',
#   '102480',
#   '0',
#   '0.6298460960388184',
#   ' 0.0',
#   ' 0.0',
#   ' 0.7767200469970703',
#   '0.048026666045188904',
#   '-0.006124264560639858',
#   '-0.08259424567222595',
#   '0.545859158039093'],
#  ['1631220938.06200004',
#   '103277',
#   '0',
#   '0.6298460960388184',
#   ' 0.0',
#   ' 0.0',
#   ' 0.7767200469970703',
#   '0.18583816289901733',
#   '-0.06738662719726562',
#   '-0.12200946360826492',
#   '0.5458237528800964'],
#  ['1631220939.05399990',
#   '104071',
#   '0',
#   '0.6298460960388184',
#   ' 0.0',
#   ' 0.0',
#   ' 0.7767200469970703',
#   '-0.04079544544219971',
#   '-0.044381435960531235',
#   '-0.07203443348407745',
#   '0.5422123670578003'],
#  ['1631220939.80599999',
#   '104868',
#   '0',
#   '0.6016390323638916',
#   ' 0.0',
# ...
#   ' 0.0',
#   ' -0.0',
#   ' -0.824712336063385',
#   '0.0071644168347120285',
#   '0.23377367854118347',
#   '0.00010714351083151996',
#   '0.0'],
#  ['1631221008.22799993',
#   '173465',
#   '0',
#   '0.5642184615135193',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8256255388259888',
#   '0.003654191270470619',
#   '0.2292502224445343',
#   '6.346860755002126e-05',
#   '0.0'],
#  ['1631221009.16699982',
#   '174263',
#   '0',
#   '0.5629088282585144',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8265190124511719',
#   '0.0021165383514016867',
#   '0.22643040120601654',
#   '3.817089964286424e-05',
#   '0.0'],
#  ['1631221009.87999988',
#   '175060',
#   '0',
#   '0.5616602301597595',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8273679614067078',
#   '0.00011395623732823879',
#   '0.22359225153923035',
#   '4.658780017052777e-05',
#   '0.0'],
#  ['1631221010.66599989',
#   '175858',
#   '0',
#   '0.5604314804077148',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8282007575035095',
#   '-0.00244709849357605',
#   '0.21498315036296844',
#   '4.976522905053571e-05',
#   '0.0'],
#  ['1631221011.53600001',
#   '176652',
#   '0',
#   '0.5592060685157776',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8290287256240845',
#   '-0.023546965792775154',
#   '0.17204266786575317',
#   '-7.19851886969991e-05',
#   '0.0'],
#  ['1631221012.27399993',
#   '177454',
#   '0',
#   '0.5580947399139404',
#   ' 0.0',
#   ' -0.0',
#   ' -0.829777181148529',
#   '-0.015287489630281925',
#   '0.19076652824878693',
#   '-6.917757855262607e-05',
#   '0.0'],
#  ['1631221013.18299985',
#   '178252',
#   '0',
#   '0.557080090045929',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8304587602615356',
#   '-0.0027376224752515554',
#   '0.2146366387605667',
#   '2.3996137315407395e-05',
#   '0.0'],
#  ['1631221014.30699992',
#   '179050',
#   '0',
#   '0.5561816096305847',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8310607671737671',
#   '0.007735571824014187',
#   '0.2353249043226242',
#   '8.770081331022084e-05',
#   '0.0'],
#  ['1631221014.76099992',
#   '179848',
#   '0',
#   '0.5552989840507507',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8316507935523987',
#   '0.016472354531288147',
#   '0.2532508671283722',
#   '0.00018258583440911025',
#   '0.0'],
#  ['1631221015.55099988',
#   '180646',
#   '0',
#   '0.5544285774230957',
#   ' 0.0',
#   ' -0.0',
#   ' -0.832231342792511',
#   '0.02257515862584114',
#   '0.26976969838142395',
#   '0.00025660154642537236',
#   '0.0'],
#  ['1631221016.37699986',
#   '181435',
#   '0',
#   '0.5536044239997864',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8327797651290894',
#   '0.026984412223100662',
#   '0.2801360785961151',
#   '0.00029598554829135537',
#   '0.0'],
#  ['1631221017.12699986',
#   '182233',
#   '0',
#   '0.5527585744857788',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8333414196968079',
#   '0.02942284382879734',
#   '0.2857525050640106',
#   '0.0002917867386713624',
#   '0.0'],
#  ['1631221017.95199990',
#   '183031',
#   '0',
#   '0.55197674036026',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8338595032691956',
#   '0.02947714738547802',
#   '0.2863856256008148',
#   '0.00029291852843016386',
#   '0.0'],
#  ['1631221018.61599994',
#   '183833',
#   '0',
#   '0.5512160062789917',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8343626260757446',
#   '0.028950942680239677',
#   '0.28344863653182983',
#   '0.0002952827198896557',
#   '0.0'],
#  ['1631221019.47899985',
#   '184631',
#   '0',
#   '0.5505146384239197',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8348255157470703',
#   '0.027777016162872314',
#   '0.27882951498031616',
#   '0.0002985961618833244',
#   '0.0'],
#  ['1631221020.25600004',
#   '185424',
#   '0',
#   '0.5499135851860046',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8352215886116028',
#   '0.02587589994072914',
#   '0.2727852761745453',
#   '0.00025455476134084165',
#   '0.0'],
#  ['1631221020.99799991',
#   '186227',
#   '0',
#   '0.5493272542953491',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8356072902679443',
#   '0.021726742386817932',
#   '0.26453807950019836',
#   '0.0002013586781686172',
#   '0.0'],
#  ['1631221021.92100000',
#   '187020',
#   '0',
#   '0.548729658126831',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8359998464584351',
#   '0.01802898570895195',
#   '0.25665274262428284',
#   '0.00017454594490118325',
#   '0.0'],
#  ['1631221022.64699984',
#   '187823',
#   '0',
#   '0.5481483936309814',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8363810777664185',
#   '0.014975293539464474',
#   '0.24891920387744904',
#   '0.000162469208589755',
#   '0.0'],
#  ['1631221023.64599991',
#   '188620',
#   '0',
#   '0.5476163029670715',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8367296457290649',
#   '0.011953834444284439',
#   '0.24141256511211395',
#   '0.00013998310896568',
#   '0.0'],
#  ['1631221024.23199987',
#   '189414',
#   '0',
#   '0.5471335649490356',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8370453119277954',
#   '0.009260515682399273',
#   '0.23493969440460205',
#   '8.083361171884462e-05',
#   '0.0'],
#  ['1631221025.04900002',
#   '190212',
#   '0',
#   '0.5467148423194885',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8373188376426697',
#   '0.006493271794170141',
#   '0.2286958247423172',
#   '5.659047747030854e-05',
#   '0.0'],
#  ['1631221025.85399985',
#   '191014',
#   '0',
#   '0.546309769153595',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8375832438468933',
#   '0.004859787877649069',
#   '0.22320611774921417',
#   '3.947514051105827e-05',
#   '0.0'],
#  ['1631221026.54099989',
#   '191808',
#   '0',
#   '0.545908510684967',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8378447890281677',
#   '0.003177178790792823',
#   '0.2176884263753891',
#   '2.688403765205294e-05',
#   '0.0'],
#  ['1631221027.45700002',
#   '192610',
#   '0',
#   '0.545478343963623',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8381249308586121',
#   '0.0019172501051798463',
#   '0.21237792074680328',
#   '1.3751733604294714e-05',
#   '0.0'],
#  ['1631221028.20799994',
#   '193399',
#   '0',
#   '0.5451182126998901',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8383592367172241',
#   '0.002436514711007476',
#   '0.20871992409229279',
#   '4.8373192839790136e-05',
#   '0.0'],
#  ['1631221029.06599998',
#   '194202',
#   '0',
#   '0.5447919964790344',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8385711908340454',
#   '0.0013176227221265435',
#   '0.20639440417289734',
#   '1.579324816702865e-05',
#   '0.0'],
#  ['1631221029.81299996',
#   '195000',
#   '0',
#   '0.5444619655609131',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8387855291366577',
#   '0.0012300072703510523',
#   '0.20390862226486206',
#   '2.157954077119939e-05',
#   '0.0'],
#  ['1631221030.60800004',
#   '195797',
#   '0',
#   '0.5442177653312683',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8389440178871155',
#   '0.0020228370558470488',
#   '0.2018541842699051',
#   '6.438266382247093e-07',
#   '0.0'],
#  ['1631221031.47399998',
#   '196591',
#   '0',
#   '0.5439687371253967',
#   ' 0.0',
#   ' -0.0',
#   ' -0.839105486869812',
#   '0.002419191412627697',
#   '0.200531005859375',
#   '2.9886325137340464e-05',
#   '0.0'],
#  ['1631221032.29999995',
#   '197393',
#   '0',
#   '0.5437062382698059',
#   ' 0.0',
#   ' -0.0',
#   ' -0.839275598526001',
#   '0.0022733709774911404',
#   '0.1989576369524002',
#   '2.4085022232611664e-05',
#   '0.0'],
#  ['1631221033.26699996',
#   '198191',
#   '0',
#   '0.5434349775314331',
#   ' 0.0',
#   ' -0.0',
#   ' -0.839451253414154',
#   '0.0029051932506263256',
#   '0.19900915026664734',
#   '1.1517528264448629e-06',
#   '0.0'],
#  ['1631221033.89899993',
#   '198989',
#   '0',
#   '0.5432299971580505',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8395838737487793',
#   '0.0024482635781168938',
#   '0.1995871514081955',
#   '3.7893885746598244e-05',
#   '0.0'],
#  ['1631221034.65400004',
#   '199782',
#   '0',
#   '0.5431026220321655',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8396663665771484',
#   '0.002906327834352851',
#   '0.19986720383167267',
#   '1.540326775284484e-05',
#   '0.0'],
#  ['1631221035.52799988',
#   '200585',
#   '0',
#   '0.5429642796516418',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8397557139396667',
#   '0.0018602929776534438',
#   '0.19913525879383087',
#   '3.1920168112264946e-05',
#   '0.0'],
#  ['1631221036.26199985',
#   '201383',
#   '0',
#   '0.5428531765937805',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8398276567459106',
#   '0.002226438606157899',
#   '0.19856375455856323',
#   '1.5353285562014207e-05',
#   '0.0'],
#  ['1631221037.02600002',
#   '202181',
#   '0',
#   '0.5427864789962769',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8398706912994385',
#   '0.0013110695872455835',
#   '0.19786089658737183',
#   '1.0479991033207625e-05',
#   '0.0'],
#  ['1631221037.82900000',
#   '202974',
#   '0',
#   '0.5426801443099976',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8399394750595093',
#   '0.0015222880756482482',
#   '0.19807177782058716',
#   '1.5717372662038542e-05',
#   '0.0'],
#  ['1631221038.61500001',
#   '203772',
#   '0',
#   '0.5425904393196106',
#   ' 0.0',
#   ' -0.0',
#   ' -0.839997410774231',
#   '0.0011101902928203344',
#   '0.19666853547096252',
#   '-4.2144861254200805e-06',
#   '0.0'],
#  ['1631221039.54499984',
#   '204575',
#   '0',
#   '0.5425366759300232',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8400321006774902',
#   '-0.00017595138342585415',
#   '0.19634416699409485',
#   '-1.032245381793473e-05',
#   '0.0'],
#  ['1631221040.36399984',
#   '205372',
#   '0',
#   '0.5425022840499878',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8400543332099915',
#   '-0.0005966131575405598',
#   '0.19553647935390472',
#   '-1.938452260219492e-05',
#   '0.0'],
#  ['1631221041.00799990',
#   '206161',
#   '0',
#   '0.5424143075942993',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8401111364364624',
#   '-0.0014042389811947942',
#   '0.19421574473381042',
#   '-5.332324690243695e-06',
#   '0.0'],
#  ['1631221041.75300002',
#   '206959',
#   '0',
#   '0.5422922968864441',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8401898741722107',
#   '-0.0014470036840066314',
#   '0.19362284243106842',
#   '-4.300043201510562e-06',
#   '0.0'],
#  ['1631221042.68099999',
#   '207762',
#   '0',
#   '0.5422687530517578',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8402051329612732',
#   '-0.0016497249016538262',
#   '0.1938057690858841',
#   '-4.554053703031968e-06',
#   '0.0'],
#  ['1631221043.36999989',
#   '208555',
#   '0',
#   '0.5422528386116028',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8402153253555298',
#   '-0.0016703682485967875',
#   '0.19402281939983368',
#   '-2.3155060262070037e-05',
#   '0.0'],
#  ['1631221044.26099992',
#   '209353',
#   '0',
#   '0.5422351956367493',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8402267694473267',
#   '-0.0022773363161832094',
#   '0.19371828436851501',
#   '-3.568790998542681e-05',
#   '0.0'],
#  ['1631221045.16199994',
#   '210151',
#   '0',
#   '0.5422284007072449',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8402311205863953',
#   '-0.002912487369030714',
#   '0.19333456456661224',
#   '-8.923365385271609e-06',
#   '0.0'],
#  ['1631221046.04799986',
#   '210953',
#   '0',
#   '0.542199969291687',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8402494788169861',
#   '-0.0023252861574292183',
#   '0.19323624670505524',
#   '-1.592434819031041e-05',
#   '0.0'],
#  ['1631221046.59299994',
#   '211751',
#   '0',
#   '0.54216468334198',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8402722477912903',
#   '-0.001972663216292858',
#   '0.19241607189178467',
#   '-1.5512598110944964e-05',
#   '0.0'],
#  ['1631221047.47399998',
#   '212549',
#   '0',
#   '0.5421631336212158',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8402732610702515',
#   '-0.0008157017291523516',
#   '0.19345253705978394',
#   '-1.544738915981725e-05',
#   '0.0'],
#  ['1631221048.12299991',
#   '213347',
#   '0',
#   '0.5422258377075195',
#   ' 0.0',
#   ' -0.0',
#   ' -0.840232789516449',
#   '-0.0010884965304285288',
#   '0.1917065978050232',
#   '-2.1458914488903247e-05',
#   '0.0'],
#  ['1631221048.91499996',
#   '214145',
#   '0',
#   '0.54228675365448',
#   ' 0.0',
#   ' -0.0',
#   ' -0.840193510055542',
#   '-3.983677743235603e-05',
#   '0.19048431515693665',
#   '1.153550101662404e-06',
#   '0.0'],
#  ['1631221049.83200002',
#   '214938',
#   '0',
#   '0.5423305630683899',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8401651978492737',
#   '0.0009033163660205901',
#   '0.19006069004535675',
#   '8.720156074559782e-06',
#   '0.0'],
#  ['1631221050.61199999',
#   '215732',
#   '0',
#   '0.5424372553825378',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8400962948799133',
#   '0.001148464041762054',
#   '0.1894531100988388',
#   '8.44342230266193e-06',
#   '0.0'],
#  ['1631221051.31399989',
#   '216530',
#   '0',
#   '0.5425163507461548',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8400452733039856',
#   '0.0010904192458838224',
#   '0.18943601846694946',
#   '1.031075771606993e-05',
#   '0.0'],
#  ['1631221052.36500001',
#   '217332',
#   '0',
#   '0.5425560474395752',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8400195837020874',
#   '0.0021105867344886065',
#   '0.1904178261756897',
#   '1.821648038458079e-05',
#   '0.0'],
#  ['1631221053.09200001',
#   '218125',
#   '0',
#   '0.5426333546638489',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8399696350097656',
#   '0.002741812262684107',
#   '0.19062645733356476',
#   '2.440765092615038e-05',
#   '0.0'],
#  ['1631221053.80599999',
#   '218923',
#   '0',
#   '0.5426966547966003',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8399287462234497',
#   '0.0035285772755742073',
#   '0.19133669137954712',
#   '1.9629740563686937e-05',
#   '0.0'],
#  ['1631221054.55799985',
#   '219721',
#   '0',
#   '0.5427314043045044',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8399063348770142',
#   '0.003408631309866905',
#   '0.19081126153469086',
#   '4.072929368703626e-05',
#   '0.0'],
#  ['1631221055.39299989',
#   '220524',
#   '0',
#   '0.5428071022033691',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8398573994636536',
#   '0.003565934021025896',
#   '0.1915075182914734',
#   '3.351240593474358e-05',
#   '0.0'],
#  ['1631221056.28900003',
#   '221322',
#   '0',
#   '0.5428761839866638',
#   ' 0.0',
#   ' -0.0',
#   ' -0.839812695980072',
#   '0.003854337614029646',
#   '0.19164147973060608',
#   '2.335303906875197e-05',
#   '0.0'],
#  ['1631221056.88199997',
#   '222120',
#   '0',
#   '0.5429783463478088',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8397467136383057',
#   '0.004249100107699633',
#   '0.1923218071460724',
#   '2.6053905457956716e-05',
#   '0.0'],
#  ['1631221057.76999998',
#   '222918',
#   '0',
#   '0.5430448055267334',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8397036790847778',
#   '0.004593428689986467',
#   '0.19285224378108978',
#   '2.4792720068944618e-05',
#   '0.0'],
#  ['1631221058.63699985',
#   '223711',
#   '0',
#   '0.543196439743042',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8396056294441223',
#   '0.003873220644891262',
#   '0.1927826702594757',
#   '2.542474976507947e-05',
#   '0.0'],
#  ['1631221059.28799987',
#   '224509',
#   '0',
#   '0.5432753562927246',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8395546078681946',
#   '0.004278259817510843',
#   '0.19335921108722687',
#   '2.2507880203193054e-05',
#   '0.0'],
#  ['1631221060.17599988',
#   '225302',
#   '0',
#   '0.5433628559112549',
#   ' 0.0',
#   ' -0.0',
#   ' -0.839497983455658',
#   '0.003996528219431639',
#   '0.192878857254982',
#   '1.0488746738701593e-05',
#   '0.0'],
#  ['1631221060.85200000',
#   '226100',
#   '0',
#   '0.5434061884880066',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8394699096679688',
#   '0.004779232200235128',
#   '0.1944071352481842',
#   '3.1900428439257666e-05',
#   '0.0'],
#  ['1631221061.68799996',
#   '226903',
#   '0',
#   '0.5435648560523987',
#   ' 0.0',
#   ' -0.0',
#   ' -0.839367151260376',
#   '0.004398916382342577',
#   '0.19459979236125946',
#   '2.8015841962769628e-05',
#   '0.0'],
#  ['1631221062.51300001',
#   '227701',
#   '0',
#   '0.543717086315155',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8392686247825623',
#   '0.004725256469100714',
#   '0.19588148593902588',
#   '4.2999286961276084e-05',
#   '0.0'],
#  ['1631221063.30199981',
#   '228499',
#   '0',
#   '0.5438398718833923',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8391890525817871',
#   '0.004917619749903679',
#   '0.19658026099205017',
#   '4.169467501924373e-05',
#   '0.0'],
#  ['1631221064.07499981',
#   '229292',
#   '0',
#   '0.5439231991767883',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8391350507736206',
#   '0.005459961015731096',
#   '0.196197509765625',
#   '2.9773909773211926e-05',
#   '0.0'],
#  ['1631221064.82999992',
#   '230094',
#   '0',
#   '0.5439876914024353',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8390932083129883',
#   '0.004661880899220705',
#   '0.19590000808238983',
#   '2.821600173774641e-05',
#   '0.0'],
#  ['1631221065.74699998',
#   '230892',
#   '0',
#   '0.5440601110458374',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8390462398529053',
#   '0.0032716155983507633',
#   '0.19608381390571594',
#   '3.2843578082975e-05',
#   '0.0'],
#  ['1631221066.45899987',
#   '231690',
#   '0',
#   '0.5441591143608093',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8389820456504822',
#   '0.0031878750305622816',
#   '0.19527216255664825',
#   '2.5726190870045684e-05',
#   '0.0'],
#  ['1631221067.24499989',
#   '232484',
#   '0',
#   '0.5442861318588257',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8388996124267578',
#   '0.0027396981604397297',
#   '0.1938793957233429',
#   '1.407354557159124e-05',
#   '0.0'],
#  ['1631221068.03099990',
#   '233282',
#   '0',
#   '0.5444029569625854',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8388238549232483',
#   '0.002578312996774912',
#   '0.1928071230649948',
#   '-4.31192847827333e-06',
#   '0.0'],
#  ['1631221068.97799993',
#   '234084',
#   '0',
#   '0.568459153175354',
#   ' 0.0',
#   ' -0.0',
#   ' -0.8227115273475647',
#   '-2.0811214447021484',
#   '0.04209456220269203',
#   '0.008068275637924671',
#   '0.0'],
#  ['1631221069.76300001',
#   '234877',
#   '0',
#   '0.18700778484344482',
#   ' 0.0',
#   ' 0.0',
#   ' 0.982358455657959',
#   '3.83972430229187',
#   '-3.5853230953216553',
#   '-0.5586258172988892',
#   '0.0']]

# %%
from google.colab import files
uploaded = files.upload()

with open(list(uploaded.keys())[0], 'r') as fr:
  text = fr.read()
  text = '['+text+']'
  text = list(uploaded.keys())[0].split('.')[0]+":"+text
  text = '{'+text+'}'
  text = text.replace('}\n{', '},{')

with open("copy_"+list(uploaded.keys())[0], 'w') as fw:
  fw.write(text)

files.download(list(uploaded.keys())[0])
# Out:
#      <input type="file" id="files-663d9be8-82d6-4d1a-aa33-7e0970a0b5b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-663d9be8-82d6-4d1a-aa33-7e0970a0b5b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ATTITUDE_TARGET.json to ATTITUDE_TARGET (1).json
